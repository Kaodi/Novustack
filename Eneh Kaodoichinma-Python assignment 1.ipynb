# %%
# import numpy and pandas as np and pd respectively
import numpy as np
import pandas as pd

# %%
# import the news csv file
news = pd.read_csv('C:/Users/dell/Downloads/news.csv')

# %%
news
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
# export the news csv file
news.to_csv('C:/Users/dell/Downloads/news2.csv')

# %%
news
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
# import a tab separated table
news_in_table = pd.read_table('C:/Users/dell/Downloads/news.csv')

# %%
news_in_table
# Out:
#                                         ,title,text,label
# 0       8476,You Can Smell Hillary’s Fear,"Daniel Gree...
# 1       In the final stretch of the election, Hillary ...
# 2       The word “unprecedented” has been thrown aroun...
# 3       But that’s exactly what Hillary and her people...
# 4       The FBI is under attack by everyone from Obama...
# ...                                                   ...
# 104116  Bush, though, needs to close the floodgates. H...
# 104117  Cullen, a former New Hampshire GOP chairman, s...
# 104118  I think it's good politics for Jeb,"" said Fer...
# 104119  O'Connell agreed. He pointed out that even if ...
# 104120  In a lot of elections, being the studious one ...
#
# [104121 rows x 1 columns]

# %%
# import a tab separated table from the news clipboard
news_clip = pd.read_clipboard('news_in_table')

# %%
news_clip
# Out:
# Empty DataFrame
# Columns: [data.rename( columns={'Unnamed: 0':'new column name'}, inplace=True )]
# Index: []

# %%
news_clip1 = pd.to_clipboard('news_in_table')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2400/2516152340.py in <module>
# ----> 1 news_clip1 = pd.to_clipboard('news_in_table')
#
# c:\python\python39\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_clipboard'

# %%
# display first two elemnts from the dataframe
news[:2]

# %%
# display all elements from the dataframe except the first two
news[2:]

# %%
# display the first five elements from the dataframe
news.head()

# %%
# display the last five elements from the dataframe
news.tail()

# %%
# show statistical summary on the numeric column 
news.describe()

# %%
news.mean()

# %%
news.min()

# %%
news.max()

# %%
news.count()
# Out:
# Unnamed: 0    6335
# title         6335
# text          6335
# label         6335
# dtype: int64

# %%
news.quantile(0.25)
# Out:
# Unnamed: 0    2674.5
# Name: 0.25, dtype: float64

# %%
news.quantile(0.5)
# Out:
# Unnamed: 0    5271.0
# Name: 0.5, dtype: float64

# %%
news.quantile(0.75)
# Out:
# Unnamed: 0    7901.0
# Name: 0.75, dtype: float64

# %%
# replace all NaN in the dataframe with a 0
news.fillna(0)
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
# drop all NaN in the dataframe
news.dropna()
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
# rename the unnamed columns 
news.rename( columns={'Unnamed: 0':'codes'}, inplace=True )
news
# Out:
#       codes                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# ...

# %%
# sort the dataframe first by codes then by title
news.sort_values(by=['codes', 'title'], ascending=True)
# Out:
#       codes                                              title  \
# 5603      2  Study: women had to drive 4 times farther afte...
# 565       3        Trump, Clinton clash in dueling DC speeches
# 2099      5  As Reproductive Rights Hang In The Balance, De...
# 2197      6  Despite Constant Debate, Americans' Abortion O...
# 5974      7  Obama Argues Against Goverment Shutdown Over P...
# ...     ...                                                ...
# 1213  10549  French Political Leader: “France is about to E...
# 4863  10551  Man with unfashionable front door feared by ne...
# 5397  10553  Obamacare Architect on Rising Premiums: It’s N...
# 208   10555  Clinton Vs. Trump: Latest Electoral Prediction...
# 1021  10557  A List of Best Password Managers Offering Both...
#
#                                                    text label
# 5603  Ever since Texas laws closed about half of the...  REAL
# 565   Donald Trump and Hillary Clinton, now at the s...  REAL
# ...

# %%
# replace no values with ''(an empty string)
news.replace('no', '')
# Out:
#       codes                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# ...

# %%
# simple filtering
news.query('codes > 9000')
# Out:
#       codes                                              title  \
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 21    10348  Episode #160 – SUNDAY WIRE: ‘Hail to the Deplo...
# 34     9016  2016 interview with Socrates: Another day of L...
# 35     9324  Mike Pence Drapes Shawl Over Immodest Lady Jus...
# ...     ...                                                ...
# 6313   9636  Donald Trump claims the election will be 'rigg...
# 6320   9051  “Nothing Good Can Come of This Election”–and T...
# 6321  10200   List of Republicans opposing Trump | OffGuardian
# 6322  10009  Putin: Use of 'mythical' Russian military thre...
# 6328   9337  Radio Derb Is On The Air–Leonardo And Brazil’s...
#
#                                                    text label
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# ...

# %%
# filtering with multiple clauses
news[(news.codes>10000) & (news['label'] == 'FAKE')]
# Out:
#       codes                                              title  \
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 21    10348  Episode #160 – SUNDAY WIRE: ‘Hail to the Deplo...
# 92    10232  Silent Counter-Coup by 17 Intel Agencies To St...
# 108   10490  Kevin MacDonald celebrates Trump’s Amazing Vic...
# ...     ...                                                ...
# 6274  10086  BREAKING: WikiLeaks Just Released Full ISIS Do...
# 6299  10289  Thousands of Wild American Bison Appear From N...
# 6304  10417  Obama Furious After Fed-Up ‘Deplorables’ Drop ...
# 6321  10200   List of Republicans opposing Trump | OffGuardian
# 6322  10009  Putin: Use of 'mythical' Russian military thre...
#
#                                                    text label
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# ...

# %%
#generating a pivot table that shows maximum label for a given title
news.pivot_table(index = 'title', values = 'label', aggfunc = max)
# Out:
#                                                    label
# title
# "America has a simple ideology": how one of Rus...  REAL
# "Political identity is fair game for hatred": h...  REAL
# "Russia is concentrating" 2.0: Putin's new poli...  FAKE
# "Top Five Clinton Donors Are Jewish" - How Anti...  FAKE
# #2816: Clinton Pride’s 8(a) Pig Farm Bridge – S...  FAKE
# ...                                                  ...
# “When You Speak Up for the MOVE 9, You Speak Up...  FAKE
# “Where is the public outcry for an explanation ...  REAL
# “Wikileaks is the Mossad, Stupid, Not the Russi...  FAKE
# “You Ruined Your Own Communities, Don’t Ruin Ou...  FAKE
# “Your little brother is not the ultimate author...  REAL
#
# [6256 rows x 1 columns]

# %%
# applying a transformation to each row in the dataframe 
news.apply(lambda x: x.codes * 1.8 + 32, axis = 1)
# Out:
# 0       15288.8
# 1       18561.2
# 2        6526.4
# 3       18287.6
# 4        1607.0
#          ...
# 6330     8114.0
# 6331    14543.6
# 6332    15551.6
# 6333     7269.8
# 6334     7826.0
# Length: 6335, dtype: float64
